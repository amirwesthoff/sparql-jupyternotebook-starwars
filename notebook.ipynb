# %%
# Import packages
from rdflib import Graph
import pandas as pd
from IPython.display import display, HTML

# %%
# Load the Star Wars data
g = Graph()
g.parse("data.ttl", format="turtle")
print(f"Graph has {len(g)} triples.")
# Out:
# Graph has 3966 triples.

# %%
# Define function to present query results
def render_sparql_html(result, query_type="SELECT"):
    """
    Renders SPARQL query results as an HTML table.
    
    Parameters:
    - result: the output of g.query(...)
    - query_type: one of "SELECT", "CONSTRUCT", "DESCRIBE"
    """
    html = "<table><tr>"

    if query_type.upper() == "SELECT":
        headers = result.vars
        html += "".join(f"<th>{h}</th>" for h in headers) + "</tr>"
        for row in result:
            html += "<tr>" + "".join(f"<td>{row.get(h, '')}</td>" for h in headers) + "</tr>"

    elif query_type.upper() in ["CONSTRUCT", "DESCRIBE"]:
        html += "<th>Subject</th><th>Predicate</th><th>Object</th></tr>"
        for s, p, o in result:
            html += f"<tr><td>{s}</td><td>{p}</td><td>{o}</td></tr>"

    else:
        raise ValueError("Unsupported query type. Use SELECT, CONSTRUCT, or DESCRIBE.")

    html += "</table>"
    display(HTML(html))

# %% [markdown]
# # Exercise 1: What does this query do?
#
# - Change the order of ?s ?p ?o
# - Play around with `LIMIT`

# %%
# Exercise 1
query = """

SELECT ?s ?p ?o
WHERE {
  # ?s ?p ?o .
}
LIMIT 5
"""

results = g.query(query)
render_sparql_html(results, query_type="SELECT")
# Out:
# <table><tr><th>s</th><th>p</th><th>o</th></tr><tr><td>https://swapi.co/resource/starship/21</td><td>https://swapi.co/vocabulary/pilot</td><td>https://swapi.co/resource/human/22</td></tr><tr><td>https://swapi.co/vocabulary/Skakoan</td><td>https://swapi.co/vocabulary/film</td><td>https://swapi.co/resource/film/5</td></tr><tr><td>https://swapi.co/resource/film/7</td><td>https://swapi.co/vocabulary/character</td><td>https://swapi.co/resource/human/14</td></tr><tr><td>https://swapi.co/resource/starship/58</td><td>https://swapi.co/vocabulary/hyperdriveRating</td><td>1.5</td></tr><tr><td>https://swapi.co/resource/zabrak/54</td><td>https://swapi.co/vocabulary/homeworld</td><td>https://swapi.co/resource/planet/45</td></tr></table>

# %% [markdown]
# # Exercise 2: Add a prefix

# %%
query = """

# Add prefix here
PREFIX voc: <replace-this-with-uri>

SELECT *
WHERE {
  # ?human a voc:Human .
}
LIMIT 5
"""

results = g.query(query)
render_sparql_html(results, query_type="SELECT")
# Out:
# <table><tr><th>human</th></tr><tr><td>https://swapi.co/resource/human/42</td></tr><tr><td>https://swapi.co/resource/human/88</td></tr><tr><td>https://swapi.co/resource/human/26</td></tr><tr><td>https://swapi.co/resource/human/28</td></tr><tr><td>https://swapi.co/resource/human/34</td></tr></table>

# %%
query = """
PREFIX voc: <https://swapi.co/vocabulary/> 

DESCRIBE <https://swapi.co/resource/human/28>
"""

results = g.query(query)
render_sparql_html(results, query_type="DESCRIBE")
# Out:
# <table><tr><th>Subject</th><th>Predicate</th><th>Object</th></tr><tr><td>https://swapi.co/resource/human/28</td><td>https://swapi.co/vocabulary/eyeColor</td><td>blue</td></tr><tr><td>https://swapi.co/resource/human/28</td><td>https://swapi.co/vocabulary/film</td><td>https://swapi.co/resource/film/3</td></tr><tr><td>https://swapi.co/resource/human/28</td><td>https://swapi.co/vocabulary/gender</td><td>female</td></tr><tr><td>https://swapi.co/resource/human/28</td><td>https://swapi.co/vocabulary/birthYear</td><td>48BBY</td></tr><tr><td>https://swapi.co/resource/human/28</td><td>https://swapi.co/vocabulary/hairColor</td><td>auburn</td></tr><tr><td>https://swapi.co/resource/human/28</td><td>http://www.w3.org/1999/02/22-rdf-syntax-ns#type</td><td>https://swapi.co/vocabulary/Human</td></tr><tr><td>https://swapi.co/resource/human/28</td><td>http://www.w3.org/2000/01/rdf-schema#label</td><td>Mon Mothma</td></tr><tr><td>https://swapi.co/resource/human/28</td><td>https://swapi.co/vocabulary/homeworld</td><td>https://swapi.co/resource/planet/32</td></tr><tr><td>https://swapi.co/resource/human/28</td><td>https://swapi.co/vocabulary/skinColor</td><td>fair</td></tr><tr><td>https://swapi.co/resource/human/28</td><td>http://www.w3.org/1999/02/22-rdf-syntax-ns#type</td><td>https://swapi.co/vocabulary/Character</td></tr><tr><td>https://swapi.co/resource/human/28</td><td>https://swapi.co/vocabulary/height</td><td>150.0</td></tr><tr><td>https://swapi.co/resource/human/28</td><td>https://swapi.co/vocabulary/desc</td><td>None</td></tr></table>

# %% [markdown]
# # Exercise 3: Which humans are in this dataset?
#
# - According to the description on the website, the dataset contains the following classes: `voc:Character, voc:Human, voc:Film, voc:Planet, voc:Starship, voc:Species, voc:Vehicle`.
# - You can find their names using `rdfs:label`

# %%
# Exercise 3
query = """

PREFIX voc: <https://swapi.co/vocabulary/> 

SELECT ?s ?p ?o
WHERE {
  # ?s ?p ?o .
}
LIMIT 5
"""

results = g.query(query)
render_sparql_html(results, query_type="SELECT")

# %% [markdown]
# # Exercise 4: Which information does an instance of a certain class appear to have?
#
# - Select a resource that you want to explore further.
# - Use the DESCRIBE query.

# %%
# Exercise 4
query = """
PREFIX voc: <https://swapi.co/vocabulary/> 

DESCRIBE <replace-with-uri>
"""

results = g.query(query)
render_sparql_html(results, query_type="DESCRIBE")
# Out:
# <table><tr><th>Subject</th><th>Predicate</th><th>Object</th></tr></table>

# %% [markdown]
# # Exercise 5: Which films featured Obi-Wan Kenobi?
#
# - Remember/copy the URI for Obi-Wan Kenobi
# - Determine how you will discover what the relationship is between a Human and a Film

# %%
# Exercise 5
query = """
PREFIX voc: <https://swapi.co/vocabulary/> 

"""

results = g.query(query)
render_sparql_html(results, query_type="SELECT")

# %% [markdown]
# # Exercise 6: Get the population number of planets in descending order and the movies in which they featured
#
# - Find the attribute for the population number for a Planet
# - Determine how you will find out what the relationship is between a Planet and a Film
# - If you don’t want to show everything, then only put the variables for the labels in the SELECT clause
# - Use ORDER BY DESC to sort the results

# %%
# Exercise 6
query = """
PREFIX voc: <https://swapi.co/vocabulary/> 

"""

results = g.query(query)
render_sparql_html(results, query_type="SELECT")

# %% [markdown]
# # Answers

# %%
# Answer Exercise 1
query = """

SELECT ?s ?p ?o
WHERE {
  # ?s ?p ?o .
}
LIMIT 5
"""

results = g.query(query)
render_sparql_html(results, query_type="SELECT")
# Out:
# <table><tr><th>s</th><th>p</th><th>o</th></tr><tr><td>https://swapi.co/resource/starship/21</td><td>https://swapi.co/vocabulary/pilot</td><td>https://swapi.co/resource/human/22</td></tr><tr><td>https://swapi.co/vocabulary/Skakoan</td><td>https://swapi.co/vocabulary/film</td><td>https://swapi.co/resource/film/5</td></tr><tr><td>https://swapi.co/resource/film/7</td><td>https://swapi.co/vocabulary/character</td><td>https://swapi.co/resource/human/14</td></tr><tr><td>https://swapi.co/resource/starship/58</td><td>https://swapi.co/vocabulary/hyperdriveRating</td><td>1.5</td></tr><tr><td>https://swapi.co/resource/zabrak/54</td><td>https://swapi.co/vocabulary/homeworld</td><td>https://swapi.co/resource/planet/45</td></tr></table>

# %%
# Answer Exercise 2
query = """

# Add prefix here
PREFIX voc: <https://swapi.co/vocabulary/> 

SELECT *
WHERE {
  # ?human a voc:Human .
}
LIMIT 5
"""

results = g.query(query)
render_sparql_html(results, query_type="SELECT")
# Out:
# <table><tr><th>human</th></tr><tr><td>https://swapi.co/resource/human/42</td></tr><tr><td>https://swapi.co/resource/human/88</td></tr><tr><td>https://swapi.co/resource/human/26</td></tr><tr><td>https://swapi.co/resource/human/28</td></tr><tr><td>https://swapi.co/resource/human/34</td></tr></table>

# %%
# Answer Exercise 3
query = """
PREFIX voc: <https://swapi.co/vocabulary/> 

SELECT ?human ?label
WHERE {
    # ?human rdf:type voc:Human .
    # ?human rdfs:label ?label .
}

"""

results = g.query(query)
render_sparql_html(results, query_type="SELECT")
# Out:
# <table><tr><th>human</th><th>label</th></tr><tr><td>https://swapi.co/resource/human/42</td><td>Quarsh Panaka</td></tr><tr><td>https://swapi.co/resource/human/88</td><td>Captain Phasma</td></tr><tr><td>https://swapi.co/resource/human/26</td><td>Lobot</td></tr><tr><td>https://swapi.co/resource/human/28</td><td>Mon Mothma</td></tr><tr><td>https://swapi.co/resource/human/34</td><td>Finis Valorum</td></tr><tr><td>https://swapi.co/resource/human/39</td><td>Ric Olié</td></tr><tr><td>https://swapi.co/resource/human/61</td><td>Cordé</td></tr><tr><td>https://swapi.co/resource/human/62</td><td>Cliegg Lars</td></tr><tr><td>https://swapi.co/resource/human/66</td><td>Dormé</td></tr><tr><td>https://swapi.co/resource/human/69</td><td>Jango Fett</td></tr><tr><td>https://swapi.co/resource/human/74</td><td>Jocasta Nu</td></tr><tr><td>https://swapi.co/resource/human/84</td><td>Finn</td></tr><tr><td>https://swapi.co/resource/human/85</td><td>Rey</td></tr><tr><td>https://swapi.co/resource/human/12</td><td>Wilhuff Tarkin</td></tr><tr><td>https://swapi.co/resource/human/19</td><td>Jek Tono Porkins</td></tr><tr><td>https://swapi.co/resource/human/29</td><td>Arvel Crynyd</td></tr><tr><td>https://swapi.co/resource/human/32</td><td>Qui-Gon Jinn</td></tr><tr><td>https://swapi.co/resource/human/43</td><td>Shmi Skywalker</td></tr><tr><td>https://swapi.co/resource/human/60</td><td>Gregar Typho</td></tr><tr><td>https://swapi.co/resource/human/68</td><td>Bail Prestor Organa</td></tr><tr><td>https://swapi.co/resource/human/81</td><td>Raymus Antilles</td></tr><tr><td>https://swapi.co/resource/human/86</td><td>Poe Dameron</td></tr><tr><td>https://swapi.co/resource/human/9</td><td>Biggs Darklighter</td></tr><tr><td>https://swapi.co/resource/human/25</td><td>Lando Calrissian</td></tr><tr><td>https://swapi.co/resource/human/51</td><td>Mace Windu</td></tr><tr><td>https://swapi.co/resource/human/6</td><td>Owen Lars</td></tr><tr><td>https://swapi.co/resource/human/67</td><td>Dooku</td></tr><tr><td>https://swapi.co/resource/human/7</td><td>Beru Whitesun lars</td></tr><tr><td>https://swapi.co/resource/human/22</td><td>Boba Fett</td></tr><tr><td>https://swapi.co/resource/human/18</td><td>Wedge Antilles</td></tr><tr><td>https://swapi.co/resource/human/21</td><td>Palpatine</td></tr><tr><td>https://swapi.co/resource/human/4</td><td>Darth Vader</td></tr><tr><td>https://swapi.co/resource/human/14</td><td>Han Solo</td></tr><tr><td>https://swapi.co/resource/human/35</td><td>Padmé Amidala</td></tr><tr><td>https://swapi.co/resource/human/5</td><td>Leia Organa</td></tr><tr><td>https://swapi.co/resource/human/11</td><td>Anakin Skywalker</td></tr><tr><td>https://swapi.co/resource/human/1</td><td>Luke Skywalker</td></tr><tr><td>https://swapi.co/resource/human/10</td><td>Obi-Wan Kenobi</td></tr></table>

# %%
# Answer Exercise 4
query = """
PREFIX voc: <https://swapi.co/vocabulary/> 

DESCRIBE <https://swapi.co/resource/human/10>

"""

results = g.query(query)
render_sparql_html(results, query_type="DESCRIBE")
# Out:
# <table><tr><th>Subject</th><th>Predicate</th><th>Object</th></tr><tr><td>https://swapi.co/resource/human/10</td><td>https://swapi.co/vocabulary/desc</td><td>Obi-Wan "Ben" Kenobi is a fictional character in the Star Wars franchise. Within the original trilogy he is portrayed by Sir Alec Guinness, while in the prequel trilogy a younger version of the character is portrayed by Ewan McGregor. In the original trilogy, he is a mentor to Luke Skywalker, to whom he introduces the ways of the Jedi. In the prequel trilogy, he is a master and friend to Anakin Skywalker. He is frequently featured as a main character in various other Star Wars media., "Sir Alec Guinnesss portrayal of Obi-Wan in the original Star Wars (1977) remains the only time an actor has received an Oscar nomination (Best Supporting Actor) for acting in a Star Wars film."</td></tr><tr><td>https://swapi.co/resource/human/10</td><td>https://swapi.co/vocabulary/film</td><td>https://swapi.co/resource/film/4</td></tr><tr><td>https://swapi.co/resource/human/10</td><td>https://swapi.co/vocabulary/eyeColor</td><td>blue-gray</td></tr><tr><td>https://swapi.co/resource/human/10</td><td>https://swapi.co/vocabulary/vehicle</td><td>https://swapi.co/resource/vehicle/38</td></tr><tr><td>https://swapi.co/resource/human/10</td><td>https://swapi.co/vocabulary/starship</td><td>https://swapi.co/resource/starship/59</td></tr><tr><td>https://swapi.co/resource/human/10</td><td>https://swapi.co/vocabulary/homeworld</td><td>https://swapi.co/resource/planet/20</td></tr><tr><td>https://swapi.co/resource/human/10</td><td>https://swapi.co/vocabulary/film</td><td>https://swapi.co/resource/film/1</td></tr><tr><td>https://swapi.co/resource/human/10</td><td>http://www.w3.org/2000/01/rdf-schema#label</td><td>Obi-Wan Kenobi</td></tr><tr><td>https://swapi.co/resource/human/10</td><td>https://swapi.co/vocabulary/skinColor</td><td>fair</td></tr><tr><td>https://swapi.co/resource/human/10</td><td>https://swapi.co/vocabulary/birthYear</td><td>57BBY</td></tr><tr><td>https://swapi.co/resource/human/10</td><td>https://swapi.co/vocabulary/starship</td><td>https://swapi.co/resource/starship/48</td></tr><tr><td>https://swapi.co/resource/human/10</td><td>https://swapi.co/vocabulary/film</td><td>https://swapi.co/resource/film/5</td></tr><tr><td>https://swapi.co/resource/human/10</td><td>https://swapi.co/vocabulary/starship</td><td>https://swapi.co/resource/starship/64</td></tr><tr><td>https://swapi.co/resource/human/10</td><td>https://swapi.co/vocabulary/mass</td><td>77.0</td></tr><tr><td>https://swapi.co/resource/human/10</td><td>https://swapi.co/vocabulary/height</td><td>182.0</td></tr><tr><td>https://swapi.co/resource/human/10</td><td>https://swapi.co/vocabulary/starship</td><td>https://swapi.co/resource/starship/74</td></tr><tr><td>https://swapi.co/resource/human/10</td><td>https://swapi.co/vocabulary/starship</td><td>https://swapi.co/resource/starship/65</td></tr><tr><td>https://swapi.co/resource/human/10</td><td>https://swapi.co/vocabulary/hairColor</td><td>auburn, white</td></tr><tr><td>https://swapi.co/resource/human/10</td><td>http://www.w3.org/1999/02/22-rdf-syntax-ns#type</td><td>https://swapi.co/vocabulary/Human</td></tr><tr><td>https://swapi.co/resource/human/10</td><td>https://swapi.co/vocabulary/gender</td><td>male</td></tr><tr><td>https://swapi.co/resource/human/10</td><td>https://swapi.co/vocabulary/film</td><td>https://swapi.co/resource/film/6</td></tr><tr><td>https://swapi.co/resource/human/10</td><td>https://swapi.co/vocabulary/film</td><td>https://swapi.co/resource/film/2</td></tr><tr><td>https://swapi.co/resource/human/10</td><td>http://www.w3.org/1999/02/22-rdf-syntax-ns#type</td><td>https://swapi.co/vocabulary/Character</td></tr><tr><td>https://swapi.co/resource/human/10</td><td>https://swapi.co/vocabulary/film</td><td>https://swapi.co/resource/film/3</td></tr></table>

# %%
# Answer Exercise 5
query = """
PREFIX voc: <https://swapi.co/vocabulary/> 

SELECT *
WHERE {
    <https://swapi.co/resource/human/10> voc:film ?film .
    # ?film rdfs:label ?filmLabel .
}

"""

results = g.query(query)
render_sparql_html(results, query_type="SELECT")
# Out:
# <table><tr><th>film</th><th>filmLabel</th></tr><tr><td>https://swapi.co/resource/film/1</td><td>A New Hope</td></tr><tr><td>https://swapi.co/resource/film/2</td><td>The Empire Strikes Back</td></tr><tr><td>https://swapi.co/resource/film/3</td><td>Return of the Jedi</td></tr><tr><td>https://swapi.co/resource/film/4</td><td>The Phantom Menace</td></tr><tr><td>https://swapi.co/resource/film/5</td><td>Attack of the Clones</td></tr><tr><td>https://swapi.co/resource/film/6</td><td>Revenge of the Sith</td></tr></table>

# %%
# Answer Exercise 6
query = """
PREFIX voc: <https://swapi.co/vocabulary/> 

SELECT ?planetLabel ?population ?filmLabel
WHERE {
    # ?planet a voc:Planet ;
        voc:population ?population ;
        voc:film ?film .
    # ?planet rdfs:label ?planetLabel .
    # ?film rdfs:label ?filmLabel .
}
ORDER BY DESC(?population)

"""

results = g.query(query)
render_sparql_html(results, query_type="SELECT")
# Out:
# <table><tr><th>planetLabel</th><th>population</th><th>filmLabel</th></tr><tr><td>Coruscant</td><td>1000000000000</td><td>Return of the Jedi</td></tr><tr><td>Coruscant</td><td>1000000000000</td><td>The Phantom Menace</td></tr><tr><td>Coruscant</td><td>1000000000000</td><td>Attack of the Clones</td></tr><tr><td>Coruscant</td><td>1000000000000</td><td>Revenge of the Sith</td></tr><tr><td>Geonosis</td><td>100000000000</td><td>Attack of the Clones</td></tr><tr><td>Naboo</td><td>4500000000</td><td>Return of the Jedi</td></tr><tr><td>Naboo</td><td>4500000000</td><td>The Phantom Menace</td></tr><tr><td>Naboo</td><td>4500000000</td><td>Attack of the Clones</td></tr><tr><td>Naboo</td><td>4500000000</td><td>Revenge of the Sith</td></tr><tr><td>Ord Mantell</td><td>4000000000</td><td>The Empire Strikes Back</td></tr><tr><td>Alderaan</td><td>2000000000</td><td>A New Hope</td></tr><tr><td>Alderaan</td><td>2000000000</td><td>Revenge of the Sith</td></tr><tr><td>Saleucami</td><td>1400000000</td><td>Revenge of the Sith</td></tr><tr><td>Kamino</td><td>1000000000</td><td>Attack of the Clones</td></tr><tr><td>Utapau</td><td>95000000</td><td>Revenge of the Sith</td></tr><tr><td>Kashyyyk</td><td>45000000</td><td>Revenge of the Sith</td></tr><tr><td>Endor</td><td>30000000</td><td>Return of the Jedi</td></tr><tr><td>Mygeeto</td><td>19000000</td><td>Revenge of the Sith</td></tr><tr><td>Cato Neimoidia</td><td>10000000</td><td>Revenge of the Sith</td></tr><tr><td>Felucia</td><td>8500000</td><td>Revenge of the Sith</td></tr><tr><td>Bespin</td><td>6000000</td><td>The Empire Strikes Back</td></tr><tr><td>Polis Massa</td><td>1000000</td><td>Revenge of the Sith</td></tr><tr><td>Tatooine</td><td>200000</td><td>A New Hope</td></tr><tr><td>Tatooine</td><td>200000</td><td>Return of the Jedi</td></tr><tr><td>Tatooine</td><td>200000</td><td>The Phantom Menace</td></tr><tr><td>Tatooine</td><td>200000</td><td>Attack of the Clones</td></tr><tr><td>Tatooine</td><td>200000</td><td>Revenge of the Sith</td></tr><tr><td>Mustafar</td><td>20000</td><td>Revenge of the Sith</td></tr><tr><td>Yavin IV</td><td>1000</td><td>A New Hope</td></tr></table>
